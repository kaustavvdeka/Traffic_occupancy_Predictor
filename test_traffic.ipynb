# %%
# ============================================================================
# TEST SCRIPT FOR PARKING MODEL
# ============================================================================

import os
from parking_model import ParkingPredictor, test_model_on_test_set

test_folder = "/Users/kaustavmanideka/Documents/projects/Collage/y/Traffic control/parkingg/test"
model_path = "/Users/kaustavmanideka/Documents/projects/Collage/y/Traffic control/parking_model.pkl"

if os.path.exists(test_folder) and os.path.exists(model_path):
    print(f"Testing {model_path} on images from {test_folder}")
    test_model_on_test_set(model_path, test_folder)
else:
    print('Make sure parkingg/test and parking_model.pkl exist!')
# Out:
# Testing /Users/kaustavmanideka/Documents/projects/Collage/y/Traffic control/parking_model.pkl on images from /Users/kaustavmanideka/Documents/projects/Collage/y/Traffic control/parkingg/test
# ...
# TESTING MODEL ON TEST DATASET
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 13
#      11 if os.path.exists(test_folder) and os.path.exists(model_path):
#      12     print(f"Testing {model_path} on images from {test_folder}")
# ---> 13     test_model_on_test_set(model_path, test_folder)
#      14 else:
#      15     print('Make sure parkingg/test and parking_model.pkl exist!')
#
# File ~/Documents/projects/Collage/y/Traffic control/parking_model.py:530, in test_model_on_test_set(model_path, test_folder)
#     528 # Load model
#     529 predictor = ParkingPredictor()
# --> 530 predictor.load_model(model_path)
#     532 # Process test images
# ...
